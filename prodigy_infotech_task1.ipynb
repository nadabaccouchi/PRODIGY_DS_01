# %% [markdown]
# # Task 1
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.
#
# # Dataset
# Sample Dataset:-https://data.worldbank.org/indicator/SP.POP.TOTL
#
# World Population records from the year 1999 to 2023
#
# | Indicator Code      | Indicator Name                                  |
# |---------------------|-------------------------------------------------|
# | SP.POP.TOTL         | Population, total                               |
# | SP.POP.TOTL.MA.IN   | Population, male                                |
# | SP.POP.TOTL.FE.IN   | Population, female                              |
# | SP.POP.TOTL.MA.ZS   | Population, male (% of total population)        |
# | SP.POP.TOTL.FE.ZS   | Population, female (% of total population)      |

# %%
#importing libraries
import pandas as pd       
import numpy as np       
import matplotlib.pyplot as plt  
import seaborn as sns    
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
#reading dataset
df = pd.read_csv('worldpopulationadata.csv')

# %%
#explorting data
df.head()
# Out:
#       Indicator Name Indicator Code Country Name Country Code        1999  \
# 0  Population, total    SP.POP.TOTL        Aruba          ABW     86867.0
# 1  Population, total    SP.POP.TOTL  Afghanistan          AFG  19262847.0
# 2  Population, total    SP.POP.TOTL       Angola          AGO  15870753.0
# 3  Population, total    SP.POP.TOTL      Albania          ALB   3108778.0
# 4  Population, total    SP.POP.TOTL      Andorra          AND     65655.0
#
#          2000        2001        2002        2003        2004  ...  \
# 0     89101.0     90691.0     91781.0     92701.0     93540.0  ...
# 1  19542982.0  19688632.0  21000256.0  22645130.0  23553551.0  ...
# 2  16394062.0  16941587.0  17516139.0  18124342.0  18771125.0  ...
# 3   3089027.0   3060173.0   3051010.0   3039616.0   3026939.0  ...
# 4     66097.0     67820.0     70849.0     73907.0     76933.0  ...
#
#          2014        2015        2016        2017        2018        2019  \
# ...

# %%
df.tail()
# Out:
#                                   Indicator Name     Indicator Code  \
# 1075  Population, female (% of total population)  SP.POP.TOTL.FE.ZS
# 1076  Population, female (% of total population)  SP.POP.TOTL.FE.ZS
# 1077  Population, female (% of total population)  SP.POP.TOTL.FE.ZS
# 1078  Population, female (% of total population)  SP.POP.TOTL.FE.ZS
# 1079  Population, female (% of total population)  SP.POP.TOTL.FE.ZS
#
#       Country Name Country Code       1999       2000       2001       2002  \
# 1075        Kosovo          XKX  48.679828  48.693897  48.737458  48.809337
# 1076   Yemen, Rep.          YEM  49.608983  49.585650  49.562762  49.540059
# 1077  South Africa          ZAF  52.599635  52.531881  52.471010  52.410702
# 1078        Zambia          ZMB  51.892511  51.848079  51.770032  51.686354
# 1079      Zimbabwe          ZWE  52.452926  52.498869  52.539531  52.571574
#
#            2003       2004  ...       2014       2015       2016       2017  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Indicator Name  1080 non-null   object
#  1   Indicator Code  1080 non-null   object
#  2   Country Name    1080 non-null   object
#  3   Country Code    1080 non-null   object
#  4   1999            1080 non-null   float64
#  5   2000            1080 non-null   float64
#  6   2001            1080 non-null   float64
#  7   2002            1080 non-null   float64
#  8   2003            1080 non-null   float64
#  9   2004            1080 non-null   float64
#  10  2005            1080 non-null   float64
#  11  2006            1080 non-null   float64
#  12  2007            1080 non-null   float64
#  13  2008            1080 non-null   float64
#  14  2009            1080 non-null   float64
#  15  2010            1080 non-null   float64
#  16  2011            1080 non-null   float64
# ...

# %%
df.shape
# Out:
# (1080, 29)

# %%
df.describe()
# Out:
#                1999          2000          2001          2002          2003  \
# count  1.080000e+03  1.080000e+03  1.080000e+03  1.080000e+03  1.080000e+03
# mean   1.118022e+07  1.133150e+07  1.148279e+07  1.163371e+07  1.178377e+07
# std    6.350511e+07  6.428660e+07  6.505511e+07  6.580472e+07  6.653373e+07
# min    3.299158e+01  3.283943e+01  3.270844e+01  3.262291e+01  3.256231e+01
# 25%    5.039037e+01  5.039942e+01  5.038195e+01  5.039273e+01  5.039216e+01
# 50%    1.127670e+05  1.127610e+05  1.127945e+05  1.127210e+05  1.134020e+05
# 75%    4.503958e+06  4.572866e+06  4.626140e+06  4.704716e+06  4.827838e+06
# max    1.252735e+09  1.262645e+09  1.271850e+09  1.280400e+09  1.288400e+09
#
#                2004          2005          2006          2007          2008  \
# count  1.080000e+03  1.080000e+03  1.080000e+03  1.080000e+03  1.080000e+03
# mean   1.193409e+07  1.208480e+07  1.223604e+07  1.238670e+07  1.253972e+07
# ...

# %%
df.columns
# Out:
# Index(['Indicator_Name', 'Indicator_Code', 'Country_Name', 'Country_Code',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Indicator Name     object
# Indicator Code     object
# Country Name       object
# Country Code       object
# 1999              float64
# 2000              float64
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# 2012              float64
# 2013              float64
# 2014              float64
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# 2023              float64
# dtype: object

# %%
print(df['Country_Name'].unique())
print("\nTotal no of unique countries:",df['Country_Name'].nunique())
# Out:
# ['Aruba' 'Afghanistan' 'Angola' 'Albania' 'Andorra' 'Argentina' 'Armenia'
#  'American Samoa' 'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan'
#  'Burundi' 'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria'
#  'Bahrain' 'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize'
#  'Bermuda' 'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan'
#  'Botswana' 'Central African Republic' 'Canada' 'Switzerland'
#  'Channel Islands' 'Chile' 'China' "Cote d'Ivoire" 'Cameroon'
#  'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros' 'Cabo Verde'
#  'Costa Rica' 'Cuba' 'Curacao' 'Cayman Islands' 'Cyprus' 'Czechia'
#  'Germany' 'Djibouti' 'Dominica' 'Denmark' 'Dominican Republic' 'Algeria'
#  'Ecuador' 'Egypt, Arab Rep.' 'Eritrea' 'Spain' 'Estonia' 'Ethiopia'
#  'Finland' 'Fiji' 'France' 'Faroe Islands' 'Micronesia, Fed. Sts.' 'Gabon'
#  'United Kingdom' 'Georgia' 'Ghana' 'Gibraltar' 'Guinea' 'Gambia, The'
# ...

# %%
print(df['Country_Code'].unique())
print("\nTotal no of unique country code:",df['Country_Code'].nunique())
# Out:
# ['ABW' 'AFG' 'AGO' 'ALB' 'AND' 'ARG' 'ARM' 'ASM' 'ATG' 'AUS' 'AUT' 'AZE'
#  'BDI' 'BEL' 'BEN' 'BFA' 'BGD' 'BGR' 'BHR' 'BHS' 'BIH' 'BLR' 'BLZ' 'BMU'
#  'BOL' 'BRA' 'BRB' 'BRN' 'BTN' 'BWA' 'CAF' 'CAN' 'CHE' 'CHI' 'CHL' 'CHN'
#  'CIV' 'CMR' 'COD' 'COG' 'COL' 'COM' 'CPV' 'CRI' 'CUB' 'CUW' 'CYM' 'CYP'
#  'CZE' 'DEU' 'DJI' 'DMA' 'DNK' 'DOM' 'DZA' 'ECU' 'EGY' 'ERI' 'ESP' 'EST'
#  'ETH' 'FIN' 'FJI' 'FRA' 'FRO' 'FSM' 'GAB' 'GBR' 'GEO' 'GHA' 'GIB' 'GIN'
#  'GMB' 'GNB' 'GNQ' 'GRC' 'GRD' 'GRL' 'GTM' 'GUM' 'GUY' 'HKG' 'HND' 'HRV'
#  'HTI' 'HUN' 'IDN' 'IMN' 'IND' 'IRL' 'IRN' 'IRQ' 'ISL' 'ISR' 'ITA' 'JAM'
#  'JOR' 'JPN' 'KAZ' 'KEN' 'KGZ' 'KHM' 'KIR' 'KNA' 'KOR' 'KWT' 'LAO' 'LBN'
#  'LBR' 'LBY' 'LCA' 'LIE' 'LKA' 'LSO' 'LTU' 'LUX' 'LVA' 'MAC' 'MAF' 'MAR'
#  'MCO' 'MDA' 'MDG' 'MDV' 'MEX' 'MHL' 'MKD' 'MLI' 'MLT' 'MMR' 'MNE' 'MNG'
#  'MNP' 'MOZ' 'MRT' 'MUS' 'MWI' 'MYS' 'NAM' 'NCL' 'NER' 'NGA' 'NIC' 'NLD'
#  'NOR' 'NPL' 'NRU' 'NZL' 'OMN' 'PAK' 'PAN' 'PER' 'PHL' 'PLW' 'PNG' 'POL'
# ...

# %%
#Data cleaning
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Indicator Name    0
# Indicator Code    0
# Country Name      0
# Country Code      0
# 1999              0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# 2023              0
# dtype: int64

# %%
df.columns = df.columns.str.replace(' ', '_')
df.head()
# Out:
#       Indicator_Name Indicator_Code Country_Name Country_Code        1999  \
# 0  Population, total    SP.POP.TOTL        Aruba          ABW     86867.0
# 1  Population, total    SP.POP.TOTL  Afghanistan          AFG  19262847.0
# 2  Population, total    SP.POP.TOTL       Angola          AGO  15870753.0
# 3  Population, total    SP.POP.TOTL      Albania          ALB   3108778.0
# 4  Population, total    SP.POP.TOTL      Andorra          AND     65655.0
#
#          2000        2001        2002        2003        2004  ...  \
# 0     89101.0     90691.0     91781.0     92701.0     93540.0  ...
# 1  19542982.0  19688632.0  21000256.0  22645130.0  23553551.0  ...
# 2  16394062.0  16941587.0  17516139.0  18124342.0  18771125.0  ...
# 3   3089027.0   3060173.0   3051010.0   3039616.0   3026939.0  ...
# 4     66097.0     67820.0     70849.0     73907.0     76933.0  ...
#
#          2014        2015        2016        2017        2018        2019  \
# ...

# %%
columns_to_drop = ['Indicator_Name', 'Country_Code']
existing_columns_to_drop = [col for col in columns_to_drop if col in df.columns]
df.drop(columns=existing_columns_to_drop, inplace=True)
df.columns
# Out:
# Index(['Indicator_Code', 'Country_Name', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023'],
#       dtype='object')

# %% [markdown]
# ## Filter and Visualize Data

# %%
# Filter data for total population
total_population_data = df[df['Indicator_Code'] == 'SP.POP.TOTL']

# Sort data based on the total population for 2022
total_population_sorted = total_population_data.sort_values(by="2023", ascending=False)

# Get the top ten countries with the highest total population for 2023
total_top_ten_countries = total_population_sorted.head(10)
print("Top ten countries of total population\n")
print(total_top_ten_countries[['Country_Name']] )
# Out:
# Top ten countries of total population
#
#            Country_Name
# 88                India
# 35                China
# 202       United States
# 86            Indonesia
# 149            Pakistan
# 141             Nigeria
# 25               Brazil
# 16           Bangladesh
# 164  Russian Federation
# 124              Mexico

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2023", y="Country_Name", data=total_top_ten_countries, palette="magma")
plt.title("Top Ten Countries of Total Population (2023)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="2017", y="Country_Name", data=total_top_ten_countries, palette="magma")
plt.title("Top Ten Countries with Total Population (2017)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# %%
# Sort data based on the total population for 2023
total_population_sorted1 = total_population_data.sort_values(by="2023", ascending=True)

# Get the bottom ten countries with the highest total population for 2023
total_bottom_ten_countries = total_population_sorted1.head(10)
print("Bottom ten countries of total population\n")
print(total_bottom_ten_countries[['Country_Name']] )
# Out:
# Bottom ten countries of total population
#
#                   Country_Name
# 197                     Tuvalu
# 146                      Nauru
# 153                      Palau
# 206     British Virgin Islands
# 118   St. Martin (French part)
# 70                   Gibraltar
# 173                 San Marino
# 120                     Monaco
# 111              Liechtenstein
# 183  Sint Maarten (Dutch part)

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2011", y="Country_Name", data=total_bottom_ten_countries, palette="cividis")
plt.title("Bottom Ten Countries of Total Population (2011)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="2001", y="Country_Name", data=total_bottom_ten_countries, palette="cividis")
plt.title("Bottom Ten Countries with Total Population (2001)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# %%
# Filter data for male population
male_population_data = df[df["Indicator_Code"] == "SP.POP.TOTL.MA.IN"]

# Sort data based on the male population for 2023
male_population_sorted = male_population_data.sort_values(by="2023", ascending=False)

# Get the top ten countries with the highest male population for 2023
male_top_ten_countries = male_population_sorted.head(10)
print("Top ten countries of male population")
print(male_top_ten_countries[['Country_Name']] )
# Out:
# Top ten countries of male population
#            Country_Name
# 304               India
# 251               China
# 418       United States
# 302           Indonesia
# 365            Pakistan
# 357             Nigeria
# 241              Brazil
# 232          Bangladesh
# 380  Russian Federation
# 276            Ethiopia

# %%
# Filter data for female population
female_population_data = df[df["Indicator_Code"] == "SP.POP.TOTL.FE.IN"]

# Sort data based on the female population for 2023
female_population_sorted = female_population_data.sort_values(by="2023", ascending=False)

# Get the top ten countries with the highest female population for 2023
female_top_ten_countries = female_population_sorted.head(10)
print("Top ten countries of female population")
print(female_top_ten_countries[['Country_Name']] )
# Out:
# Top ten countries of female population
#            Country_Name
# 520               India
# 467               China
# 634       United States
# 518           Indonesia
# 581            Pakistan
# 573             Nigeria
# 457              Brazil
# 448          Bangladesh
# 596  Russian Federation
# 556              Mexico

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2023", y="Country_Name", data=male_top_ten_countries, palette="crest")
plt.title("Top Ten Countries with Highest Male Population (2023)",size=10)
plt.xlabel("Male Population",size=10)
plt.ylabel("Country",size=10)
plt.show()

plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="2023", y="Country_Name", data=female_top_ten_countries, palette="crest")
plt.title("Top Ten Countries with Highest Female Population (2023)",size=10)
plt.xlabel("Female Population",size=10)
plt.ylabel("Country",size=10)
plt.show()

# %%
male_lowest_ten_countries = male_population_sorted.tail(10)
print("Top ten countries of lowest male population")
print(male_lowest_ten_countries[['Country_Name']] )
# Out:
# Top ten countries of lowest male population
#                  Country_Name
# 341          Marshall Islands
# 327             Liechtenstein
# 336                    Monaco
# 389                San Marino
# 286                 Gibraltar
# 334  St. Martin (French part)
# 422    British Virgin Islands
# 369                     Palau
# 362                     Nauru
# 413                    Tuvalu

# %%
female_lowest_ten_countries = female_population_sorted.tail(10)
print("Top ten countries of lowest female population")
print(female_lowest_ten_countries[['Country_Name']] )
# Out:
# Top ten countries of lowest female population
#                   Country_Name
# 543              Liechtenstein
# 615  Sint Maarten (Dutch part)
# 552                     Monaco
# 605                 San Marino
# 550   St. Martin (French part)
# 502                  Gibraltar
# 638     British Virgin Islands
# 585                      Palau
# 578                      Nauru
# 629                     Tuvalu

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2023", y="Country_Name", data=male_lowest_ten_countries, palette="viridis")
plt.title("Top Ten Countries with Lowest Male Population (2023)",size=10)
plt.xlabel("Male Population",size=10)
plt.ylabel("Country",size=10)
plt.show()

plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="2023", y="Country_Name", data=female_lowest_ten_countries, palette="viridis")
plt.title("Top Ten Countries with Lowest Female Population (2023)",size=10)
plt.xlabel("Female Population",size=10)
plt.ylabel("Country",size=10)
plt.show()

# %%
# Merge male and female population data on 'Country_Name'
merged_data = pd.merge(male_population_data, female_population_data, on="Country_Name", suffixes=("_male", "_female"))

# %%
merged_data
# Out:
#     Indicator_Code_male  Country_Name   1999_male   2000_male   2001_male  \
# 0     SP.POP.TOTL.MA.IN         Aruba     41816.0     42833.0     43513.0
# 1     SP.POP.TOTL.MA.IN   Afghanistan   9667811.0   9815442.0   9895467.0
# 2     SP.POP.TOTL.MA.IN        Angola   7799340.0   8054751.0   8322504.0
# 3     SP.POP.TOTL.MA.IN       Albania   1542851.0   1531486.0   1516640.0
# 4     SP.POP.TOTL.MA.IN       Andorra     34163.0     34285.0     35151.0
# ..                  ...           ...         ...         ...         ...
# 211   SP.POP.TOTL.MA.IN        Kosovo    969222.0    935457.0    943362.0
# 212   SP.POP.TOTL.MA.IN   Yemen, Rep.   9128106.0   9391539.0   9655431.0
# 213   SP.POP.TOTL.MA.IN  South Africa  21977029.0  22221377.0  22447806.0
# 214   SP.POP.TOTL.MA.IN        Zambia   4628537.0   4762771.0   4915581.0
# 215   SP.POP.TOTL.MA.IN      Zimbabwe   5570832.0   5621605.0   5653006.0
#
#       2002_male   2003_male   2004_male   2005_male   2006_male  ...  \
# ...

# %%
# Calculate the total population for each country (male + female)
merged_data["Total Population"] = merged_data["2022_male"] + merged_data["2022_female"]

# %%
merged_data.head()
# Out:
#   Indicator_Code_male Country_Name  1999_male  2000_male  2001_male  \
# 0   SP.POP.TOTL.MA.IN        Aruba    41816.0    42833.0    43513.0
# 1   SP.POP.TOTL.MA.IN  Afghanistan  9667811.0  9815442.0  9895467.0
# 2   SP.POP.TOTL.MA.IN       Angola  7799340.0  8054751.0  8322504.0
# 3   SP.POP.TOTL.MA.IN      Albania  1542851.0  1531486.0  1516640.0
# 4   SP.POP.TOTL.MA.IN      Andorra    34163.0    34285.0    35151.0
#
#     2002_male   2003_male   2004_male   2005_male   2006_male  ...  \
# 0     43950.0     44327.0     44663.0     45069.0     45591.0  ...
# 1  10562202.0  11397483.0  11862726.0  12302104.0  12828447.0  ...
# 2   8603948.0   8904704.0   9226105.0   9564193.0   9917959.0  ...
# 3   1512520.0   1508084.0   1503547.0   1497909.0   1490629.0  ...
# 4     36773.0     38429.0     40082.0     41679.0     41829.0  ...
#
#    2015_female  2016_female  2017_female  2018_female  2019_female  \
# 0      54828.0      55224.0      55591.0      55935.0      56254.0
# ...

# %%
# Sort data based on total population in descending order
sorted_data = merged_data.sort_values(by="Total Population", ascending=False)

# Select the top 10 countries with the highest total population
top_10_countries = sorted_data.head(10)

# %%
# Create the stacked bar plot
plt.figure(figsize=(12, 6))

sns.barplot(x="Country_Name", y="2023_female", data=top_10_countries, color="purple", label="Female Population")
sns.barplot(x="Country_Name", y="2023_male", data=top_10_countries, bottom=top_10_countries["2023_female"], color="pink", label="Male Population")
plt.title("Top 10 Countries with Male and Female Populations (2023)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
# Select the bottom 10 countries with the highest total population
bottom_10_countries = sorted_data.tail(10)

# %%
# Create the stacked bar plot
plt.figure(figsize=(12, 6))

sns.barplot(x="Country_Name", y="2023_female", data=bottom_10_countries, color="orange", label="Female Population")
sns.barplot(x="Country_Name", y="2023_male", data=bottom_10_countries, bottom=bottom_10_countries["2023_female"], color="green", label="Male Population")
plt.title("Bottom 10 Countries with Male and Female Populations (2023)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()
